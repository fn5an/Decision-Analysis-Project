# %% [markdown]
# # A Decision Tool for Emotion Regulation Intervention
#
# - Project proposal for University of Virginia SYS 6014 Decision Analysis Spring 2020
#
#
# Fateme Nikseresht, March 2020

# %% [markdown]
# ## Abstract

# %% [markdown]
# ## Introduction
#
# Nowadays, self-tracking technologies are commonly used in areas like fitness and personal health. In this project, I am going to use self-tracking to enhance user's emotions. People do have an interest in utilizing technology to improve their emotions in different situations. I, however, advocate for a stronger focus on users to self-track their emotions at work, home, party and etc. For this purpose, users' physical signals which are collected in real-time with the smart band are used.
# As there are plenty of existing researches in emotion recognition using physical signals, I assumed that the user's emotion elicitated from their physiological signals. Therefore, my main focus will be on designing a decision-making system to enhance the user's emotion. To achieve this, my decision tool system will send feedback to the user, considering her profile, preferences, and environment. In other words, the decision making tool decides which approach works effectively for a specific type of emotion and a certain user.

# %% [markdown]
# ## Data Set
#
# I simulated a data set contains 60 participants. The simulated data-set reflects participant's age group, gender, four various emotion types with two different stages(Extremely Bored, Bored, Extremely Amused, Amused, Extremely relaxed, Relaxed, Extremely Scared, Scared). I am going to possibly use it to drive behavioral changes.

# %% [markdown]
# ## Problem Framework
#
#
# - **Action Set (Decision):**
# *$A$: { $a_1$, $a_2$, ….., $a_n$}* <br> *${a_1}$= FeedBack Type 1, $a_2$= FeedBack Type 2, …………., $a_n$= FeedBack Type N*
# *$A_t$= $Argmin(X_{t+1}-X^d)^2$*
#
#
# - **Current Emotion Type:**
# *${X}$: { $x_1$,…., $x_8$}*
# *${X_m}$= $Argmax(p(x_m))$*
#
#
# - **State Space (Detcted Emotion Type):**
# *$\hat{X}$: { $\hat{x_1}$,…., $\hat{x_8}$}* <br> *$\hat{x_1}$= Emotion type(Extremely Bored), $\hat{x_2}$= Emotion type 2(Extremely Amused), $\hat{x_3}$= Emotion type 3(Extremely relaxed), $\hat{x_4}$= Emotion type 4(Extremely Scared), $\hat{x_5}$= Emotion type 5(Bored), $\hat{x_6}$= Emotion type 6(Amused), $\hat{x_7}$= Emotion type 7(Relaxed), $\hat{x_8}$= Emotion type 8(Scared)*
# *$\hat{X_m}$$\approx$${X_m}$*
# *$X_t$= $g(X_{t-1},A_{t-1})$*
#
#
# - **Parameter Space (Probabilithy of Emotion Type):**
# *${Θ}$: {$p(x_1)$, $p(x_2)$, ………….,  $p(x_8)$}*
# *$P(x_m)$ = $h(s_z,f_q)$*
#
#
# - **Physiological Signals:**
# *${S}$: { $s_1$,…., $s_i$}* <br> *$s_1$= Signal type 1(EDA), …………., $s_i$= Signal type I*
#
#
# - **Users' Profile (User's age group and gender):**
# *${F}$: { $f_1$,…., $f_{60}$}* <br> *$f_1$= First user's profile, $f_2$= Second user's profile, …………., $f_{60}$= 60th user's profile*
#
#
# - **Users' Circumstances (User's current environment):**
# *${C}$: { $c_1$,…., $c_j$}* <br> *$c_1$= Environment type 1, …………., $c_{j}$= Environment type J*
#
#
# - **Users' Prefrences (User's feedback prefrence):**
# *${R}$: { $r_1$,…., $r_{60}$}* <br> *$r_1$= 1st user's prefrence, …………., $r_{60}$= 60th user's prefrence*
#
#
# - **Desired Emotion:**
# *$X^d$*
#
#
# - **Loss Function:**
# *$L$= $min{\sum_t}(X_{t+1}-X^d)^2$*

# %% [markdown]
# ## System Diagram
#
#
# <img src="Slide2.jpg" width="800" height="1000">

# %% [markdown]
# # Script

# %% [markdown]
# ### Data Simulation

# %% [markdown]
# ##### Importing required libraries

# %%
import pandas as pd
import os, sys
import random

# %% [markdown]
# ##### Read a profile CSV file which contains participants' ID numbers, genders, and age group .

# %%
data = pd.read_csv('D:/Dropbox/Bias Data/Simulation.csv')
data = data.set_index('Participant-ID')
#data

# %% [markdown]
# ##### Create a data frame which contains eight diffrent emotion status(four emotion type with two stage) for each participant. Each participant will experience all othis emotion status but in a rendom sequence.

# %%
status = ["bored-1", "amused-1", "relaxed-1", "scared-1", "bored-2", "amused-2", "relaxed-2", "scared-2"]
emotion = pd.DataFrame()
for x in range(60):
    emotion = pd.concat([emotion, pd.DataFrame(status).transpose()], axis=0)
    random.shuffle(status)
    
emotion = emotion.rename(columns={0:'Status1',1:'Status2',2:'Status3',3:'Status4',4:'Status5',5:'Status6',6:'Status7',7:'Status8'})    
o = pd.Series(range(1,61))
emotion.index=o
#emotion

# %%
score = ["1", "2", "3", "4", "5"]
prefrences = pd.DataFrame()
for x in range(60):
    prefrences = pd.concat([prefrences, pd.DataFrame(score).transpose()], axis=0)
    random.shuffle(score)
    
prefrences = prefrences.rename(columns={0:'Listen to Music',1:'Drink Coffee',2:'Drink Water',3:'Sleep/Have a rest',4:'Exercise'})    
o = pd.Series(range(1,61))
prefrences.index=o
#prefrences

# %% [markdown]
# ##### Concatenate profile dataframe with emotion status dataframe.

# %%
df= pd.concat([data, prefrences, emotion], axis=1 )
df
# Out:
#    Sex Age-Group Listen to Music Drink Coffee Drink Water Sleep/Have a rest  \
# 1    F     30-34               1            2           3                 4
# 2    F     25-29               3            4           1                 5
# 3    F     30-34               5            3           2                 4
# 4    F     20-24               1            2           4                 3
# 5    M     20-24               3            5           2                 4
# 6    M     30-34               4            5           1                 2
# 7    M     25-29               5            4           3                 2
# 8    F     25-29               1            3           2                 5
# 9    F     20-24               4            3           2                 1
# 10   M     35-39               2            5           1                 4
# 11   M     25-29               5            2           3                 4
# 12   M     25-29               4            3           1                 5
# 13   F     25-29               1            4           3                 2
# 14   M     20-24               1            4           2                 3
# 15   F     20-24               2            4           3                 5
# 16   F     20-24               5            4           3                 2
# 17   F     20-24               3            2           4                 1
# 18   M     25-29               5            4           1                 3
# 19   F     20-24               1            2           3                 4
# 20   M     35-39               1            4           5                 3
# 21   M     20-24               3            4           5                 1
# 22   F     20-24               2            1           4                 3
# 23   M     25-29               1            5           2                 4
# 24   F     25-29               1            4           3                 5
# 25   F     25-29               3            5           2                 1
# 26   M     25-29               3            1           5                 2
# 27   M     25-29               3            1           2                 4
# 28   M     25-29               1            2           4                 5
# 29   M     25-29               1            3           2                 5
# 30   F     25-29               5            2           4                 3
# 31   F     30-34               5            3           2                 1
# 32   F     15-19               4            2           5                 1
# 33   F     20-24               1            5           3                 2
# 34   F     15-19               1            5           3                 4
# 35   M     30-34               2            1           5                 3
# 36   M     35-39               5            1           4                 2
# 37   M     15-19               1            3           5                 4
# 38   F     15-19               4            1           2                 5
# 39   F     35-39               4            3           5                 1
# 40   M     20-24               1            2           4                 3
# 41   M     15-19               1            4           2                 3
# 42   M     35-39               4            2           5                 3
# 43   F     20-24               3            4           5                 2
# 44   M     20-24               3            5           4                 1
# 45   F     35-39               5            2           4                 1
# 46   F     30-34               4            1           2                 3
# 47   F     15-19               5            3           1                 2
# 48   M     15-19               5            3           2                 1
# 49   F     35-39               1            5           3                 2
# 50   M     35-39               1            4           3                 5
# 51   M     30-34               3            4           1                 5
# 52   F     20-24               3            1           4                 2
# 53   M     15-19               2            1           4                 5
# 54   F     30-34               5            1           2                 3
# 55   F     15-19               3            1           4                 5
# 56   M     20-24               5            3           2                 1
# 57   M     30-34               1            4           5                 2
# 58   M     20-24               3            4           5                 2
# 59   M     15-19               3            2           1                 4
# 60   F     15-19               3            2           4                 1
#
#    Exercise    Status1    Status2    Status3    Status4    Status5    Status6  \
# 1         5    bored-1   amused-1  relaxed-1   scared-1    bored-2   amused-2
# 2         2   amused-2   amused-1   scared-2   scared-1  relaxed-1    bored-1
# 3         1   amused-1   amused-2  relaxed-2   scared-1    bored-2   scared-2
# 4         5   scared-2  relaxed-1  relaxed-2   amused-2   amused-1    bored-2
# 5         1    bored-2    bored-1   scared-2   amused-1   scared-1  relaxed-1
# 6         3   amused-2   amused-1  relaxed-1    bored-1  relaxed-2   scared-1
# 7         1   amused-1  relaxed-1  relaxed-2    bored-1   amused-2    bored-2
# 8         4  relaxed-1   amused-2   amused-1  relaxed-2    bored-1   scared-2
# 9         5   amused-1   amused-2   scared-1  relaxed-2   scared-2    bored-1
# 10        3   amused-1  relaxed-1    bored-2   scared-2    bored-1   scared-1
# 11        1   amused-2    bored-2  relaxed-1   scared-2   amused-1  relaxed-2
# 12        2    bored-1    bored-2   amused-1   scared-2  relaxed-2   amused-2
# 13        5    bored-1   scared-2   amused-1  relaxed-2   scared-1  relaxed-1
# 14        5  relaxed-1   amused-1   scared-1   amused-2    bored-1    bored-2
# 15        1    bored-1  relaxed-1   amused-1    bored-2   amused-2  relaxed-2
# 16        1   amused-1  relaxed-2   scared-1    bored-2   amused-2    bored-1
# 17        5    bored-1   scared-2  relaxed-1    bored-2   amused-1   scared-1
# 18        2   scared-2    bored-2   amused-2   amused-1   scared-1  relaxed-2
# 19        5  relaxed-1   amused-1    bored-2    bored-1  relaxed-2   scared-1
# 20        2    bored-2   scared-1   amused-2    bored-1   amused-1   scared-2
# 21        2  relaxed-1    bored-1   scared-2    bored-2  relaxed-2   amused-2
# 22        5   scared-2   amused-1  relaxed-2  relaxed-1    bored-1   amused-2
# 23        3  relaxed-2  relaxed-1   amused-2    bored-2   scared-2   scared-1
# 24        2   amused-1   scared-1   amused-2  relaxed-2    bored-1    bored-2
# 25        4  relaxed-2   amused-1    bored-2   scared-2   amused-2  relaxed-1
# 26        4   amused-2   scared-2    bored-1   scared-1  relaxed-2    bored-2
# 27        5    bored-1   amused-1  relaxed-2   scared-1  relaxed-1    bored-2
# 28        3  relaxed-1    bored-1   scared-1   amused-1   scared-2  relaxed-2
# 29        4   amused-2  relaxed-1   amused-1    bored-1   scared-1   scared-2
# 30        1    bored-1   amused-1    bored-2   amused-2   scared-1  relaxed-1
# 31        4   scared-2    bored-2  relaxed-1   amused-2    bored-1   amused-1
# 32        3    bored-2    bored-1   scared-1  relaxed-1   amused-2   scared-2
# 33        4    bored-1   amused-2  relaxed-2   scared-2   scared-1  relaxed-1
# 34        2    bored-2   scared-2   amused-2    bored-1   scared-1  relaxed-1
# 35        4   scared-2    bored-2  relaxed-2   scared-1  relaxed-1    bored-1
# 36        3    bored-1   scared-2  relaxed-1   amused-1   amused-2   scared-1
# 37        2   amused-2   scared-2  relaxed-1  relaxed-2   amused-1    bored-1
# 38        3    bored-2   amused-1   amused-2  relaxed-2   scared-1    bored-1
# 39        2   amused-2   scared-2   amused-1    bored-2  relaxed-1    bored-1
# 40        5   amused-2   amused-1   scared-1    bored-1   scared-2  relaxed-1
# 41        5   amused-2   scared-2   scared-1    bored-1   amused-1  relaxed-1
# 42        1   amused-1  relaxed-2    bored-1   amused-2   scared-2    bored-2
# 43        1   scared-1   amused-2   amused-1  relaxed-1  relaxed-2   scared-2
# 44        2  relaxed-1   amused-2  relaxed-2   amused-1    bored-1    bored-2
# 45        3  relaxed-2   amused-1   scared-2  relaxed-1   scared-1    bored-1
# 46        5   amused-2  relaxed-1   amused-1    bored-2   scared-2   scared-1
# 47        4    bored-2   amused-2  relaxed-2   amused-1   scared-1  relaxed-1
# 48        4   amused-1  relaxed-1   scared-1    bored-2   scared-2   amused-2
# 49        4   amused-2  relaxed-2    bored-2   amused-1   scared-1   scared-2
# 50        2   amused-1  relaxed-2   amused-2  relaxed-1   scared-2    bored-2
# 51        2    bored-2   amused-2   scared-2    bored-1   scared-1  relaxed-2
# 52        5    bored-1   amused-2   amused-1  relaxed-2   scared-1  relaxed-1
# 53        3    bored-2    bored-1  relaxed-2   scared-2   amused-1   scared-1
# 54        4   amused-1   amused-2   scared-2   scared-1    bored-1  relaxed-2
# 55        2   scared-2    bored-1   amused-2   amused-1   scared-1    bored-2
# 56        4  relaxed-1   scared-2    bored-1  relaxed-2   amused-1   scared-1
# 57        3    bored-1    bored-2   scared-2   scared-1  relaxed-1  relaxed-2
# 58        1   amused-1   amused-2  relaxed-1  relaxed-2   scared-1    bored-1
# 59        5    bored-1  relaxed-2   scared-2   amused-2  relaxed-1    bored-2
# 60        5   scared-1   amused-2    bored-1   amused-1  relaxed-1  relaxed-2
#
#       Status7    Status8
# 1   relaxed-2   scared-2
# 2   relaxed-2    bored-2
# 3   relaxed-1    bored-1
# 4     bored-1   scared-1
# 5   relaxed-2   amused-2
# 6     bored-2   scared-2
# 7    scared-2   scared-1
# 8    scared-1    bored-2
# 9   relaxed-1    bored-2
# 10   amused-2  relaxed-2
# 11   scared-1    bored-1
# 12   scared-1  relaxed-1
# 13    bored-2   amused-2
# 14   scared-2  relaxed-2
# 15   scared-2   scared-1
# 16  relaxed-1   scared-2
# 17  relaxed-2   amused-2
# 18    bored-1  relaxed-1
# 19   scared-2   amused-2
# 20  relaxed-1  relaxed-2
# 21   amused-1   scared-1
# 22    bored-2   scared-1
# 23    bored-1   amused-1
# 24   scared-2  relaxed-1
# 25   scared-1    bored-1
# 26  relaxed-1   amused-1
# 27   amused-2   scared-2
# 28    bored-2   amused-2
# 29    bored-2  relaxed-2
# 30   scared-2  relaxed-2
# 31   scared-1  relaxed-2
# 32   amused-1  relaxed-2
# 33    bored-2   amused-1
# 34   amused-1  relaxed-2
# 35   amused-2   amused-1
# 36    bored-2  relaxed-2
# 37    bored-2   scared-1
# 38   scared-2  relaxed-1
# 39   scared-1  relaxed-2
# 40    bored-2  relaxed-2
# 41  relaxed-2    bored-2
# 42  relaxed-1   scared-1
# 43    bored-2    bored-1
# 44   scared-2   scared-1
# 45   amused-2    bored-2
# 46  relaxed-2    bored-1
# 47   scared-2    bored-1
# 48    bored-1  relaxed-2
# 49    bored-1  relaxed-1
# 50   scared-1    bored-1
# 51  relaxed-1   amused-1
# 52   scared-2    bored-2
# 53   amused-2  relaxed-1
# 54    bored-2  relaxed-1
# 55  relaxed-1  relaxed-2
# 56   amused-2    bored-2
# 57   amused-1   amused-2
# 58    bored-2   scared-2
# 59   scared-1   amused-1
# 60   scared-2    bored-2
